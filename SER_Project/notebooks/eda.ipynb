# %%
import pandas as pd

df = pd.read_csv("../features.csv")
print(df.head())
# Out:
#    03-01-01-01-01-01-01  -726.2172241210938  68.54141998291016  \
# 0  03-01-01-01-01-02-01         -719.128296          70.201569
# 1  03-01-01-01-02-01-01         -714.995728          69.689346
# 2  03-01-01-01-02-02-01         -710.975281          67.564880
# 3  03-01-02-01-01-01-01         -759.921753          75.783524
# 4  03-01-02-01-01-02-01         -735.006592          79.093048
#
#    3.2933976650238037  12.205300331115723  5.51027774810791  \
# 0            1.168397           13.122543          7.836950
# 1            3.924564           11.924190          6.421723
# 2            5.782241           13.230727          6.190845
# 3            6.023604           14.557394          6.454188
# 4            8.141050           11.413549          5.174124
#
#    13.667409896850586  -2.98382830619812  3.098029136657715  \
# 0           14.411290          -4.111360           4.468973
# 1           11.011614          -2.878103           4.509558
# ...
